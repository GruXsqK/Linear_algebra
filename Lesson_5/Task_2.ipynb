# %% [markdown]
# ## Дополнительное практическое задание к уроку 5

# %%
import numpy as np
from sklearn import datasets
from pandas import DataFrame

# %%
iris = datasets.load_iris()
iris_frame = DataFrame(datasets.load_iris().data)
iris_frame.columns = iris.feature_names
iris_frame['target'] = iris.target
iris_frame['name'] = iris_frame.target.apply(lambda x : iris.target_names[x])
iris_frame.head(10)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1
#
#    target    name
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa
# 5       0  setosa
# 6       0  setosa
# 7       0  setosa
# 8       0  setosa
# 9       0  setosa

# %% [markdown]
# Определим матрицу признаков

# %%
A = np.array(iris_frame[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']])
print(f'Ранг матрицы признаков: {np.linalg.matrix_rank(A)}')
# Out:
# Ранг матрицы признаков: 4

# %%
U, s, V = np.linalg.svd(A)
print(f'Признаки:\n{s}')
print(f'Вес признаков:\n{[itm/sum(s) for itm in s]}')
# Out:
# Признаки:
# [95.95991387 17.76103366  3.46093093  1.88482631]
# Вес признаков:
# [0.8059340691495326, 0.14916876798004958, 0.029067159767294914, 0.015830003103122967]

# %% [markdown]
# Можем избавиться от 2 признаков, т.к. их вес в сумме менее 5%

# %%
s[-2:] = 0
D = np.zeros_like(A, dtype=float)
D[np.diag_indices(min(A.shape))] = s
A_new = np.dot(np.dot(U, D), V)
print(f'Ранг новой матрицы признаков: {np.linalg.matrix_rank(A_new)}')
# Out:
# Ранг новой матрицы признаков: 2

# %% [markdown]
# Найдем ковариационную матрицу, и сделаем сингулярное разложение

# %%
A_cov = np.cov(A_new, rowvar=False)
U_cov, s_cov, V_cov = np.linalg.svd(A_cov)
print(f'Ковариационная матрица:\n{A_cov}')
# Out:
# Ковариационная матрица:
# [[ 0.68222377 -0.0208085   1.28603382  0.52241054]
#  [-0.0208085   0.13721124 -0.34521301 -0.15395272]
#  [ 1.28603382 -0.34521301  3.10979132  1.2939947 ]
#  [ 0.52241054 -0.15395272  1.2939947   0.53951014]]

# %%
print(f'Получили матрицу перехода:\n{V_cov}')
# Out:
# Получили матрицу перехода:
# [[-0.36356257  0.08751286 -0.85655868 -0.35562761]
#  [-0.71605943 -0.66010344  0.17801903  0.1408246 ]
#  [ 0.07877261 -0.19314343  0.32918864 -0.9209372 ]
#  [-0.59065729  0.72062512  0.35531859 -0.07464655]]

# %%
print(np.dot(A_new, V_cov))
# Out:
# [[-4.37162073 -1.99385986 -3.20713842 -2.62443402]
#  [-4.05130344 -1.79076734 -2.92341748 -2.60276413]
#  [-4.01839078 -1.82540772 -2.94171863 -2.43437125]
#  [-3.93387802 -1.72323382 -2.8253224  -2.57410972]
#  [-4.35833905 -1.99953512 -3.20742501 -2.58133753]
#  [-4.72065564 -2.09617774 -3.41457861 -3.00422674]
#  [-4.05161727 -1.82581294 -2.95348557 -2.49847039]
#  [-4.28075866 -1.91497582 -3.10847016 -2.6819726 ]
#  [-3.73310597 -1.63533531 -2.68116976 -2.44258718]
#  [-4.10142358 -1.8107271  -2.9577081  -2.64153312]
#  [-4.6276393  -2.10671782 -3.39161791 -2.78983547]
#  [-4.17661492 -1.84176704 -3.01008849 -2.69641468]
#  [-3.9978629  -1.77842278 -2.89449576 -2.5346719 ]
#  [-3.70258236 -1.72349505 -2.74604538 -2.11867767]
#  [-4.95547201 -2.3683294  -3.72794956 -2.65109865]
#  [-5.08352083 -2.37080944 -3.77408233 -2.89537574]
#  [-4.6952584  -2.18933718 -3.48549046 -2.67542714]
#  [-4.36981474 -1.98124496 -3.19573329 -2.65864734]
#  [-4.84623635 -2.1530363  -3.50635086 -3.08086773]
#  [-4.50205859 -2.04985926 -3.29984566 -2.71319449]
#  [-4.51444337 -1.96823394 -3.23432164 -2.98188802]
#  [-4.45828775 -2.00660964 -3.24782708 -2.75662539]
#  [-4.11195572 -1.99285671 -3.11702945 -2.11702231]
#  [-4.30132099 -1.82487614 -3.03851223 -2.99210885]
#  [-4.19566285 -1.77189746 -2.9569046  -2.94301438]
#  [-4.11924858 -1.76914708 -2.9282884  -2.80104283]
#  [-4.283496   -1.86645616 -3.06793192 -2.83259914]
#  [-4.43321656 -1.99552946 -3.22973731 -2.74051283]
#  [-4.3849024  -1.9881846  -3.20685183 -2.66753051]
#  [-4.0374387  -1.75553814 -2.88853474 -2.68097095]
#  [-4.05072038 -1.74986288 -2.88824814 -2.72406744]
#  [-4.49813278 -1.98958386 -3.2469673  -2.88591486]
#  [-4.68681163 -2.19195268 -3.48482313 -2.650994  ]
#  [-4.88636076 -2.30814074 -3.65273996 -2.69542656]
#  [-4.0996176  -1.7981122  -2.94630296 -2.67574644]
#  [-4.17778104 -1.92357596 -3.08042715 -2.45380807]
#  [-4.58625751 -2.11698756 -3.3861738  -2.67774975]
#  [-4.30489851 -1.98719056 -3.1785033  -2.5132453 ]
#  [-3.76872151 -1.68925989 -2.73951117 -2.3511697 ]
#  [-4.33600519 -1.93993528 -3.14879701 -2.7158515 ]
#  [-4.30821891 -1.97957536 -3.1731344  -2.54256853]
#  [-3.52840811 -1.48716142 -2.48413876 -2.48378501]
#  [-3.85265121 -1.75052933 -2.82073807 -2.33273453]
#  [-4.32184887 -1.87186108 -3.0857351  -2.89180819]
#  [-4.52564984 -1.94408492 -3.21752868 -3.0762074 ]
#  [-3.99425093 -1.75319298 -2.87168549 -2.60309854]
#  [-4.51021389 -2.0391843  -3.29352284 -2.76118107]
#  [-3.96949356 -1.7771584  -2.88366381 -2.48269224]
#  [-4.57239278 -2.08175836 -3.35129106 -2.75595656]
#  [-4.23244451 -1.90763096 -3.08558467 -2.60899028]
#  [-5.48326546 -1.45624128 -3.12962389 -6.41894251]
#  [-5.13728171 -1.34044933 -2.91171356 -6.08548259]
#  [-5.39694672 -1.34145248 -3.00182252 -6.59289431]
#  [-4.2342448  -0.98178081 -2.29470094 -5.38410455]
#  [-5.03101816 -1.21958006 -2.77185866 -6.23843173]
#  [-4.58630863 -1.06842403 -2.48978206 -5.81677394]
#  [-5.13489267 -1.28692997 -2.86513909 -6.24099922]
#  [-3.90570331 -1.06353248 -2.25166441 -4.49357428]
#  [-5.1318415  -1.30040404 -2.87560923 -6.19466642]
#  [-4.22820933 -1.04011626 -2.342497   -5.19761092]
#  [-3.80578906 -0.91937334 -2.09408155 -4.72872332]
#  [-4.75807147 -1.22425217 -2.68203629 -5.68792353]
#  [-4.47393054 -1.11378809 -2.48993716 -5.46007671]
#  [-4.86015221 -1.13970197 -2.64484186 -6.1416851 ]
#  [-4.51588318 -1.28370803 -2.64962033 -5.03387836]
#  [-5.25651312 -1.42059776 -3.02121377 -6.07992368]
#  [-4.61137983 -1.07950421 -2.50787184 -5.83288651]
#  [-4.57961104 -1.19375291 -2.59462273 -5.42843088]
#  [-4.60714019 -0.98418321 -2.42492538 -6.10990062]
#  [-4.37068369 -1.11652937 -2.45679292 -5.24892175]
#  [-4.87467906 -1.10793775 -2.62268    -6.26532772]
#  [-4.77554819 -1.28471117 -2.73972929 -5.54129007]
#  [-4.81367849 -1.00788739 -2.51618072 -6.44492637]
#  [-4.82179933 -1.13429705 -2.62703869 -6.08247605]
#  [-5.00230053 -1.32035469 -2.84813941 -5.88030891]
#  [-5.15930175 -1.36500358 -2.94027347 -6.05526235]
#  [-5.21126233 -1.26049362 -2.86878843 -6.47025493]
#  [-5.24722616 -1.21237918 -2.84001714 -6.68498062]
#  [-4.79040108 -1.14870733 -2.6285658  -5.97761972]
#  [-4.44430382 -1.27789789 -2.62005021 -4.91057016]
#  [-4.26712301 -1.08422505 -2.39358058 -5.14206053]
#  [-4.26257969 -1.12012981 -2.42271368 -5.02564731]
#  [-4.56330045 -1.21510283 -2.60726838 -5.33245772]
#  [-4.74276124 -0.93508383 -2.42956599 -6.5234676 ]
#  [-4.50088678 -1.02958529 -2.42721813 -5.76512869]
#  [-4.99841933 -1.28926603 -2.8202279  -5.96574512]
#  [-5.27375506 -1.33811328 -2.95662474 -6.36073669]
#  [-4.70161423 -1.08829705 -2.54640391 -5.9839354 ]
#  [-4.58959457 -1.19789345 -2.60159396 -5.43566027]
#  [-4.3181745  -1.04305025 -2.37592783 -5.36566939]
#  [-4.38734257 -0.99314043 -2.35703456 -5.65103808]
#  [-4.89576774 -1.19362655 -2.70318327 -6.05026762]
#  [-4.52768491 -1.16117825 -2.54892697 -5.4238752 ]
#  [-3.91898499 -1.05785722 -2.25137782 -4.53667077]
#  [-4.47004934 -1.08269943 -2.46202565 -5.54551292]
#  [-4.65299639 -1.21217795 -2.63559798 -5.51752576]
#  [-4.60922556 -1.16892833 -2.5835794  -5.56095666]
#  [-4.89180748 -1.27043577 -2.7674857  -5.81255109]
#  [-4.03730729 -1.2013408  -2.41471032 -4.33972813]
#  [-4.5609114  -1.16158347 -2.56069392 -5.48797435]
#  [-5.20117979 -0.8706277  -2.53202935 -7.61751779]
#  [-4.62685023 -0.84732021 -2.31469688 -6.55834975]
#  [-5.51813208 -1.05214868 -2.79615234 -7.69714861]
#  [-5.02056508 -0.92955255 -2.52032336 -7.08609529]
#  [-5.17849764 -0.91306688 -2.56051405 -7.4458886 ]
#  [-5.83880986 -1.01391697 -2.87369086 -8.44194244]
#  [-4.01121795 -0.72638458 -1.99970636 -5.71024872]
#  [-5.61747548 -1.01611814 -2.79949615 -8.00028365]
#  [-5.0863904  -0.8602718  -2.48372106 -7.42288105]
#  [-5.83064235 -1.16387714 -2.99908341 -7.97697509]
#  [-5.22159415 -1.16259514 -2.78864696 -6.78362749]
#  [-4.97102799 -0.95049726 -2.52120207 -6.92602299]
#  [-5.32699527 -1.07042974 -2.74608363 -7.2667123 ]
#  [-4.47951872 -0.77176627 -2.19946596 -6.49491943]
#  [-4.65978514 -0.81488043 -2.29828465 -6.72019876]
#  [-5.17362828 -1.05321126 -2.67864877 -7.01678834]
#  [-5.16667367 -1.03339606 -2.65931848 -7.06243562]
#  [-6.23431848 -1.24804943 -3.2097922  -8.51849389]
#  [-5.74163294 -0.82123817 -2.67556977 -8.82771802]
#  [-4.52839368 -0.81781499 -2.25563185 -6.4531423 ]
#  [-5.47525813 -1.08484912 -2.80937119 -7.51498247]
#  [-4.54381743 -0.86200083 -2.29870741 -6.35118787]
#  [-5.81828198 -0.96693203 -2.82646799 -8.5422431 ]
#  [-4.89219022 -1.03131214 -2.56319221 -6.52913116]
#  [-5.41034191 -1.09079472 -2.7921412  -7.36958044]
#  [-5.66907557 -1.15293242 -2.93419353 -7.69215229]
#  [-4.87255924 -1.06027725 -2.58120677 -6.40383477]
#  [-4.90759172 -1.07329737 -2.60437884 -6.4337206 ]
#  [-5.02842879 -0.8860326  -2.48582136 -7.23183174]
#  [-5.57605923 -1.1634725  -2.91123283 -7.47776102]
#  [-5.61625255 -1.0444077  -2.82326035 -7.91319366]
#  [-6.32937558 -1.39306773 -3.36644006 -8.27122537]
#  [-5.0266228  -0.8734177  -2.47441623 -7.26604506]
#  [-4.95227165 -1.05321183 -2.60256514 -6.58167342]
#  [-4.79140144 -0.83818907 -2.36344985 -6.90913695]
#  [-5.85869786 -1.13009593 -2.97984726 -8.13324849]
#  [-5.21955339 -1.00703676 -2.65495979 -7.24528729]
#  [-5.15339199 -1.03907132 -2.65960507 -7.01933913]
#  [-4.84599589 -1.07162777 -2.58177995 -6.31764179]
#  [-5.41785734 -1.14931378 -2.8447519  -7.20917372]
#  [-5.31464494 -1.01497044 -2.69442686 -7.40845567]
#  [-5.39519743 -1.19395356 -2.87512552 -7.03100066]
#  [-4.62685023 -0.84732021 -2.31469688 -6.55834975]
#  [-5.43271023 -1.01330994 -2.73358841 -7.64550337]
#  [-5.40311796 -1.04033512 -2.74652066 -7.50643372]
#  [-5.24908885 -1.09011006 -2.7361304  -7.05466033]
#  [-4.81280385 -0.93413794 -2.45283222 -6.66397955]
#  [-5.14401376 -1.07803584 -2.6896921  -6.88426256]
#  [-5.15341424 -1.04127192 -2.661494   -7.01279526]
#  [-4.80979729 -0.97679873 -2.48826921 -6.53036258]]
